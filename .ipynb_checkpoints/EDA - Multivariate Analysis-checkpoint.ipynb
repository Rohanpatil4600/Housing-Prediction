# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df= pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat               vatika gurgaon   sector 83   1.40
# 1          flat                  rof aalayas  sector 102   0.45
# 2          flat  bestech park view residency    sector 2   1.40
# 3          flat      la vida by tata housing  sector 113   1.65
# 4          flat                  m3m heights   sector 65   2.15
#
#    price_per_sqft     area                                       areaWithType  \
# 0          6628.0  2112.25             Super Built up area 1735(161.19 sq.m.)
# 1          8404.0   535.46  Super Built up area 597(55.46 sq.m.)Carpet are...
# 2          7865.0  1780.04             Super Built up area 1780(165.37 sq.m.)
# 3         10449.0  1579.10  Super Built up area 1579(146.69 sq.m.)Built Up...
# 4         15003.0  1433.05                 Built Up area: 1433 (133.13 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 0        3         3       2       7.0         NaN  Relatively New
# 1        2         2       1      14.0       North  Relatively New
# 2        3         3      3+       6.0       North    Old Property
# 3        3         2       2       3.0  North-East  Relatively New
# 4        2         2      3+      28.0        East       Undefined
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1735.0            NaN          NaN           0             0
# 1                597.0            NaN        535.4           0             0
# 2               1780.0            NaN          NaN           0             0
# 3               1579.0         1420.0       1220.0           0             0
# 4                  NaN         1433.0          NaN           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1            74
# 1           0           0       0                2            57
# 2           0           0       0                2           107
# 3           0           0       0                0            49
# 4           0           0       0                0            48

# %% [markdown]
# # property_type vs price

# %%
sns.barplot(x=df['property_type'],y=df['price'],estimator= np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'],y=df['price'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price'>

# %% [markdown]
# # property_type vs area

# %%
sns.barplot(x=df['property_type'],y=df['area'],estimator= np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='area'>

# %%
sns.boxplot(x=df['property_type'],y=df['built_up_area'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='built_up_area'>

# %%
df=df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'],y=df['built_up_area'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# # property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'],y=df['price_per_sqft'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_sqft'>

# %%
df['price_per_sqft'].sort_values(ascending=False)
# Out:
# 425     600000.0
# 2974    400000.0
# 3263    315789.0
# 2073    308333.0
# 3659    290948.0
#           ...
# 2968         NaN
# 3039         NaN
# 3041         NaN
# 3193         NaN
# 3467         NaN
# Name: price_per_sqft, Length: 3677, dtype: float64

# %%
# data errors not outliers
df[df['price_per_sqft']>100000].head(5)
# Out:
#     property_type                 society     sector  price  price_per_sqft  \
# 174         house             independent  sector 38   8.00        230547.0
# 403         house       vatika india next  sector 82   7.00        194444.0
# 425         house  emaar the palm springs  sector 54  24.00        600000.0
# 534         house             independent  sector 23   2.80        161849.0
# 679         house    bhim nagar, sector 6   sector 6   0.85        126865.0
#
#       area                                       areaWithType  bedRoom  \
# 174  347.0  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...       10
# 403  360.0  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...        4
# 425  400.0                         Plot area 400(37.16 sq.m.)        5
# 534  173.0  Plot area 173(16.07 sq.m.)Built Up area: 160 s...        5
# 679   67.0                           Plot area 67(6.22 sq.m.)        5
#
#      bathroom balcony  floorNum      facing   agePossession  \
# 174        10      3+       1.0       North       Undefined
# 403         4      3+       3.0  North-East  Relatively New
# 425         5       2       1.0  North-East    Old Property
# 534         5      3+       2.0  North-East    Old Property
# 679         2       2       1.0         NaN    Old Property
#
#      super_built_up_area  built_up_area  carpet_area  study room  \
# 174                  NaN          347.0        215.0           0
# 403                  NaN         3900.0       3743.0           0
# 425                  NaN          400.0          NaN           1
# 534                  NaN          160.0        150.0           0
# 679                  NaN           67.0          NaN           0
#
#      servant room  store room  pooja room  others  furnishing_type  \
# 174             0           0           0       0                0
# 403             1           0           0       0                2
# 425             1           0           1       0                1
# 534             0           0           1       0                1
# 679             0           0           1       0                0
#
#      luxury_score
# 174             0
# 403           105
# 425           122
# 534            74
# 679            29

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='floorNum'>

# %%
df[(df['property_type']=='house')&(df['floorNum']>10)]
# Out:
#      property_type                  society      sector  price  \
# 94           house  indiabulls centrum park  sector 103   3.25
# 188          house           ats tourmaline  sector 109   1.87
# 329          house              spaze privy   sector 72   3.10
# 831          house         suncity township   sector 54   2.00
# 970          house   vatika the seven lamps   sector 82   1.60
# 1347         house              greenopolis   sector 89   0.70
# 1473         house               ninex city   sector 76   1.75
# 1668         house      satya the hermitage  sector 103   3.15
# 1670         house              spaze privy   sector 72   3.09
# 2178         house          godrej meridien  sector 106   5.60
# 2185         house        suncity avenue 76   sector 76   0.75
# 2843         house              independent   sector 92   1.80
# 3202         house           dlf the arbour   sector 63   8.50
# 3446         house      ireo victory valley   sector 67   8.00
#
#       price_per_sqft    area  \
# 94            8125.0  4000.0
# 188           8697.0  2150.0
# 329           8486.0  3653.0
# 831          30968.0   646.0
# 970           6597.0  2425.0
# 1347          5397.0  1297.0
# 1473          6250.0  2800.0
# 1668          6702.0  4700.0
# 1670          6981.0  4426.0
# 2178         14000.0  4000.0
# 2185         10067.0   745.0
# 2843          7627.0  2360.0
# 3202         21519.0  3950.0
# 3446         22222.0  3600.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 94                         Plot area 4000(371.61 sq.m.)        4         3
# 188                  Built Up area: 2150 (199.74 sq.m.)        3         4
# 329                        Plot area 3653(339.37 sq.m.)        5         5
# 831   Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 970                        Plot area 2425(225.29 sq.m.)        4         4
# 1347                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 1473                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 1668                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 1670  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 2178                       Plot area 4000(371.61 sq.m.)        5         4
# 2185  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 2843                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 3202                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 3446                        Plot area 400(334.45 sq.m.)        6         7
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 94        3+      20.0         NaN  Under Construction                  NaN
# 188        0      12.0         NaN           Undefined                  NaN
# 329       3+      21.0         NaN      Relatively New                  NaN
# 831        3      11.0       North      Relatively New                  NaN
# 970       3+      16.0       North      Moderately Old                  NaN
# 1347       2      14.0  North-East           Undefined                  NaN
# 1473       0      14.0         NaN           Undefined                  NaN
# 1668       0      12.0        East           Undefined                  NaN
# 1670      3+      14.0        East      Relatively New                  NaN
# 2178      3+      33.0  North-East        New Property                  NaN
# 2185       2      11.0  North-East        New Property                  NaN
# 2843       0      13.0         NaN           Undefined                  NaN
# 3202      3+      27.0         NaN           Undefined                  NaN
# 3446      3+      51.0  North-East      Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 94           4000.0          NaN           0             0           0
# 188          2150.0          NaN           0             0           0
# 329          3653.0          NaN           0             0           0
# 831            60.0         59.0           0             1           0
# 970          2425.0          NaN           0             1           0
# 1347         1297.0          NaN           0             0           0
# 1473            NaN       2800.0           0             0           0
# 1668         4700.0          NaN           0             0           0
# 1670         3653.0       2922.0           0             1           0
# 2178         4000.0          NaN           1             1           1
# 2185          745.0          NaN           0             0           0
# 2843         2360.0          NaN           0             0           0
# 3202         3950.0          NaN           0             0           0
# 3446         3600.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 94             0       0                0            51
# 188            0       0                0             0
# 329            0       0                0             0
# 831            0       0                2             7
# 970            0       0                0            94
# 1347           0       0                0             0
# 1473           0       0                0             0
# 1668           0       0                0            61
# 1670           0       0                1            33
# 2178           1       0                0           151
# 2185           0       0                0            40
# 2843           0       0                0             0
# 3202           0       0                0            61
# 3446           1       0                1            49

# %%
# houses but in apartments

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <AxesSubplot:xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <AxesSubplot:xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <AxesSubplot:xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <AxesSubplot:xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='luxury_score'>

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <AxesSubplot:xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['bedRoom'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['agePossession'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['furnishing_type'].astype('category'))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <AxesSubplot:xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(df['luxury_score'],df['price'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='luxury_score', ylabel='price'>

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# super_built_up_area    0.769431
# bathroom               0.589830
# built_up_area          0.551683
# bedRoom                0.522928
# servant room           0.400992
# price_per_sqft         0.391282
# pooja room             0.341538
# store room             0.309152
# study room             0.258656
# furnishing_type        0.254638
# luxury_score           0.094787
# area                   0.034726
# others                -0.003473
# carpet_area           -0.011344
# floorNum              -0.110026
# Name: price, dtype: float64

# %%
sns.pairplot(df)
